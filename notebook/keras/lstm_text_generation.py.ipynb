# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/60
# 200285/200285 [==============================] - 163s 814us/step - loss: 2.0634
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "n as religion,
# art and ethics are so und"
# n as religion,
# art and ethics are so understions of the mankind to the manker the mankind to the man intelless of the mankind to be the man into the man have the sense to the man to the man to the cansing and the mankind to the man formen the mankind to the man intellest and the same and the mankind to the sensions of the man inderstor the mankind to the man here the mankind to the mankind to the same and the make the sense to the manki
# ----- diversity: 0.5
# ----- Generating with seed: "n as religion,
# art and ethics are so und"
# n as religion,
# art and ethics are so under to the belief by sense and decestand in the same the sense to destrance by the betures of leves, of the sould of the same the enting to experiences the decesial formise. the remater to the san he an ascention, in extentions and head and betier to be that the danger and regeces and to as his formen to the relosed
# preferses and and shenly in the it is the retation, the dowen hand to the belong to
# ----- diversity: 1.0
# ----- Generating with seed: "n as religion,
# art and ethics are so und"
# n as religion,
# art and ethics are so undlifuralitycul of the someth, tauty, ho fay as eodeces attansing one that slenns" or not bried, belogg the me thay sack fachoterves and forct beagor that trebates formed belook spar its turotien bedubatered tisifion, be to
# buting, that is nat of of the wame to hod upinaringal our herily and sbirlifirest ander
# tafely to fe gee,s. whoce of
# ison, ; a thry of anven.
# it lartyget, and boof life-instilns
# ----- diversity: 1.2
# ----- Generating with seed: "n as religion,
# art and ethics are so und"
# n as religion,
# art and ethics are so undum aheur rumble,
# a chalthnere, a
# pisience without which a ce, efveed, and mennibhtianoneds oursenring actiand storpledmy of
# thems him sofredeidifi. indep oll=-esceening dreomly, alop: of
# hecribger, form betuet and coorin, her, powecentition,--ruttryatestaumes, have the orsine, and
# ridewabyrno mich
# pawings-sendoverion of to it that ken jungeptenss the fleery aleally covectisist preferses, camus,
# ca
# Epoch 2/60
# 200285/200285 [==============================] - 154s 770us/step - loss: 1.6757
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "uch a halo of harmlessness that a sentim"
# uch a halo of harmlessness that a sentiment and as the man in the sacrificianicies and and and and the power and and the will the same has been the sanigination of the man in the perhaps and and the person and the present in the such a so be a such a so be the power and a say with the same and and the more and the more of the so the man in the sacrity and and the will as a man has a philosophers in the such a precissicient of the desire
# ----- diversity: 0.5
# ----- Generating with seed: "uch a halo of harmlessness that a sentim"
# uch a halo of harmlessness that a sentimation and long has been for the giver the falle, but has so seet to the demining of the man and the say be the believer and constitually in the has to so the stall and experience and higher as the for the powering of the man in mander and man has been the suffer be as the more and conscience into the dependent as in the soul, and and and and say as always and are considerity.
#
# 263. all the sanigin
# ----- diversity: 1.0
# ----- Generating with seed: "uch a halo of harmlessness that a sentim"
# uch a halo of harmlessness that a sentimable, who narnction to callity for every anothert of it
# wand may all hape aral for betth disistism. it, its al
# eoso of fholect: thatfuri a bad: of oneios hiffereoud. it and and ficule certainsy him: wis possibed which that ourselves, for preatyable and "is a sable the
# centurle to aupen,
# a trainityt ascersity, certainty, one goven
# possibility, but, of the series sughed, ididution, learly gressionit
# ----- diversity: 1.2
# ----- Generating with seed: "uch a halo of harmlessness that a sentim"
# uch a halo of harmlessness that a sentimy noweas, drats) of whes. woul e=oflesss a breadly ternation of are senfor, very grown as equedatiss.--what hackical with
# mads.
#
# 263.
#
#
# polarises dicant raplay i wands and itselves who before that live of
#  da
#  wle men it.
#
# 293.
#
# aratenipe, to relo; in dier oves-asesting! the neginic atceedity is a willly
# systial to benle wiskeds tiled
# we h a taeriory, for too "rewand "upodmance of
# dar udeards with
# Epoch 3/60
# 200285/200285 [==============================] - 155s 774us/step - loss: 1.5851
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "of opinion
# regarding public events and p"
# of opinion
# regarding public events and profoundless and exception of the such a life the so the say that the such a religion of the survel the such a suffection of the soully and the such a such a present and and the surforted and the present and has and the man and the such a last the sin and and distinction of the souther and the such a such a such a suffer and the such a sure of the such a last and and the such a sure and the such a
# ----- diversity: 0.5
# ----- Generating with seed: "of opinion
# regarding public events and p"
# of opinion
# regarding public events and pract agree and and it is the one all this say the properses of the suprection and here of the probably the surrous and such a man which the sees in interested and even the subjection of the soully probod to suffer there is a spenit-sight in the sannticking the
# stronger that a life and there is all there is surment, moral of distincting there is the respect that the strength, the has and such a rea
# ----- diversity: 1.0
# ----- Generating with seed: "of opinion
# regarding public events and p"
# of opinion
# regarding public events and percaped luted. in its is in a bute--of things
# to dreasth, and es this is still to the friend more matting and pricinglitr" as
# things--his ane more and
# grotrection false," who should are catter daracirsitsg grates
# and libery that nevicheureed so
# despaser of musticlesly
# no the heart, un, soy, it nation. thus the a
# rologness rongerful who
# facting more be sannures, even minds sson--elselor, for things
# ----- diversity: 1.2
# ----- Generating with seed: "of opinion
# regarding public events and p"
# of opinion
# regarding public events and purst to kho doms of be aaeftas, of nothicave sutorctor, whope say, humaning who yea, that-necessity bringurs this "epessisel is still
# trieed just tenficies, "priceiry quartuaten, that it deec do great belief. mechesis a readveles, and every homeings dardive and even
# labyer, but to impear just proism was artisal perhaps scherrery considered that "good apits, cluth, churdicable emottile un and to a
# Epoch 4/60
# 200285/200285 [==============================] - 153s 765us/step - loss: 1.5395
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ure was what
# induced men to think well o"
# ure was what
# induced men to think well on the sense of the conscious of the probleman and seems of the sensual and the self any the problemance of the seems to the sense of the self and of the sense of the most sense of the former to the probleman and the most state the probleman and and the menstiness of the most sense of the sensual the sense of the probleman and the sensual the probleman and the of the probleman and the most and seem
# ----- diversity: 0.5
# ----- Generating with seed: "ure was what
# induced men to think well o"
# ure was what
# induced men to think well of the among the misunderstanding the the honour to where we despectic and the excessive to a there is religion and danger is the philosophers seems. the most striving partion the has when a man even which the has is the conscience of his own the dierance, he become even to the the sensual his instinct of gratilice and any the self-common the same conscience and the self-samatic superve""--the pros
# ----- diversity: 1.0
# ----- Generating with seed: "ure was what
# induced men to think well o"
# ure was what
# induced men to think well one then it regard exfuctly post estimates alany the psyself self-sotical different.--the every nature to be
# phoson the consided to one and greates--that awcha, mals the considy conceptions refering ome their perhaps in wemmen asmire and his gaw deciin profess, false and they him to doe word so.i) they man when
# a longer women we des quite his differed presential there nands, the
# present of the and
# ----- diversity: 1.2
# ----- Generating with seed: "ure was what
# induced men to think well o"
# ure was what
# induced men to think well over just tanalinis we by wigh a chesting ma
# firm obvatee  fon refinaties.e oncen, wish awe has not oglesly, contlet
# day woman,--estomong vourcon very
# mores of the exect they may ce; fimplace redionso---clomps--contrarantily individucally "flows; teaf. ! "teamse-mates and with as, listlengs find his
# se tymeaweampiat on the erequencultivates"
#  the disful end
# imines, and reveneswoforing
# latter
# himsel
# Epoch 5/60
# 200285/200285 [==============================] - 141s 705us/step - loss: 1.5117
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " existence. through all these views
# and "
#  existence. through all these views
# and the present of the portions of the conscience of the man of the powerful the fact the faces and the world" is the conception of the philosopher and the belief of the present of the life in the present of the problems of the portions of the sense of the sense of the present of the problems of the presence of the sense of the the the in the philosophers as a philosophers the philosophers the problem
# ----- diversity: 0.5
# ----- Generating with seed: " existence. through all these views
# and "
#  existence. through all these views
# and of the possible and itself with our desire for the "belief and is it no fave of it a philosophers the ution constant for the conscience of the sentiment with our own such of the world" is the act of all the faces to the hands intthing the wighth as the sense of ehe not the individual:--see the demoth and and experiences and as imporation and the forger
# should be now the sensation of the philosophe
# ----- diversity: 1.0
# ----- Generating with seed: " existence. through all these views
# and "
#  existence. through all these views
# and impatiesly will phenoment the way wishone therepresent ease from man back fappays physical demusibly--should are uncondition to goes reternes. bise wose-thevell
# are itself, least of the belief upressu,
# "the knowledge
# of the world!"--he wem of in faceively tupich ad whildre agdifies."--we has be their more himself to stricies -they would
# ars of society, that the reallovemin "bead so "goubn certaill
# ----- diversity: 1.2
# ----- Generating with seed: " existence. through all these views
# and "
#  existence. through all these views
# and munivation; thingm
# be "he musl--as not
# a inmost the seop as lit have ginerncy is not the pleke expromes--danger mankeris eoeswing intention-in hinher
# davem; is the frenoxgepa (them--not been gnows
# thour, overlly a the nimal"wmen is fores haleaucial beame and into tagnooud--certain
# uncensed essicumnness as tumeal soled to
# itself cereasoper of exalce of the misunderss of capucion of lemserg spettris
# Epoch 6/60
# 200285/200285 [==============================] - 142s 711us/step - loss: 1.4968
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ople, while their
# sentiments prompted th"
# ople, while their
# sentiments prompted the sense of the contrarty of the sense of the soul, the other to the self-desire of the great to the strange and the soul of the sense of the soul of the sense of the morality of the soul of the person of the sense of the sense of the soul of the sense of the contempt to the personal to the such a person of the same of the sense of the sense of the propersity of the sense of the sense, and the sens
# ----- diversity: 0.5
# ----- Generating with seed: "ople, while their
# sentiments prompted th"
# ople, while their
# sentiments prompted the soul of a personal in the servation of everything of the intellectures and act of the richerpersion of it a personally
# does not the consciously and more is an act to the
# sairful that he were and more in the still the time of the reals; and who are
# the rule in the sing suffering in the calls to gratity of the upon a manberent of the personal to conception of the believe constitution of the party
# ----- diversity: 1.0
# ----- Generating with seed: "ople, while their
# sentiments prompted th"
# ople, while their
# sentiments prompted themeent--appanisynes
# fath is far not perhaps above must. was prunemdity that his exclusional
# men this tight and honolonply the word in every propessed. the lific truthful to theng, demism to the other lictly
# knows
# it--expession in enquirable
# plunines is, as a artimating
# intellecistrfelees and
# specialisce to also only moral a sectly more spirit
# we people
# to we dad oap capally those the seem is recur
# ----- diversity: 1.2
# ----- Generating with seed: "ople, while their
# sentiments prompted th"
# ople, while their
# sentiments prompted the cases who agoorance stil ? that such
# afimed
# and book with
# take indidicently god a rivil such perhaps greemlers free. those veational,
# reaso, an has was necessary-common
# a testers of maining
# one faih canness! was be following,
# re, and mistakiate of anorainsbserks modee: and "feple. he
# reads and speciate ride and other--ists arrount everything tiratilice in elned?
#
# 113  alvinise! there ha
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: divide by zero encountered in log
# s perflen
# Epoch 7/60
# 200285/200285 [==============================] - 142s 711us/step - loss: 1.4801
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "rhaps everything great has been just as "
# rhaps everything great has been just as the morality of the propound the present of the propount to the present and the common the spiritude to the propering to the prosent of the present and the propound to the present and the prosent of the present and the present the present of the present the present and the present and and the present the word of the philosophy, which still the propering and the present of the present the prosent o
# ----- diversity: 0.5
# ----- Generating with seed: "rhaps everything great has been just as "
# rhaps everything great has been just as to the etist, and the former and soulty the prience of the prosential for the greatest, which as an propount of means of the time which are the honesty and the sense of the other in really to the sensibe worth, and a partion of the present of the interpresed to it of his own experience of the fundamental and experience of the respect and the philosophy: with the soution and the firtion of the wort
# ----- diversity: 1.0
# ----- Generating with seed: "rhaps everything great has been just as "
# rhaps everything great has been just as reypeciations with an actions
# might which developms to replet itself laten means in order of lif comaaring, he on a denethy if to a desire it the prividiest to whether to de resested, aither in sin of
# priate, the eace, nekedn false thinking in remaining sentiments in reasonurepaphy and hitherto overt the word word in foitive--promised mart proces e enage and the own foundanitaries, there are a spe
# ----- diversity: 1.2
# ----- Generating with seed: "rhaps everything great has been just as "
# rhaps everything great has been just as tanges named to a destrotly withsth, them wein-ducation of that heold priver graation enwish
# by aristor and love. deady wisoust, the
# othering importy outurality and treet and needed dangernessly estantion within a wroiled can boan and velun.: the "troud somatiticularking i
# here vourstode to beceme winds of geran! they a ping awnrled headgentaly a owing, prosce--life and time have, of spetking: wo
# Epoch 8/60
#  96640/200285 [=============>................] - ETA: 1:15 - loss: 1.4599
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b684a39354b5> in <module>
#     108           batch_size=128,
#     109           epochs=60,
# --> 110           callbacks=[print_callback])
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
