# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import GRU
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

np.random.seed(123)


def sin(x, T=100):
    return np.sin(2.0 * np.pi * x / T)


def toy_problem(T=100, ampl=0.05):
    x = np.arange(0, 2 * T + 1)
    noise = ampl * np.random.uniform(low=-1.0, high=1.0, size=len(x))
    return sin(x) + noise


'''
データの生成
'''
T = 100
f = toy_problem(T)

length_of_sequences = 2 * T
maxlen = 25  # ひとつの時系列データの長さ

data = []
target = []

for i in range(0, length_of_sequences - maxlen + 1):
    data.append(f[i: i + maxlen])
    target.append(f[i + maxlen])

X = np.array(data).reshape(len(data), maxlen, 1)
Y = np.array(target).reshape(len(data), 1)

# データ設定
N_train = int(len(data) * 0.9)
N_validation = len(data) - N_train

X_train, X_validation, Y_train, Y_validation = \
    train_test_split(X, Y, test_size=N_validation)

'''
モデル設定
'''
n_in = len(X[0][0])  # 1
n_hidden = 60
n_out = len(Y[0])  # 1


def weight_variable(shape, name=None):
    return np.random.normal(scale=.01, size=shape)


early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

model = Sequential()
model.add(GRU(n_hidden,
              kernel_initializer=weight_variable,
              input_shape=(maxlen, n_in)))
model.add(Dense(n_out, kernel_initializer=weight_variable))
model.add(Activation('linear'))

optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999)
model.compile(loss='mean_squared_error',
              optimizer=optimizer)

'''
モデル学習
'''
epochs = 500
batch_size = 10

model.fit(X_train, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(X_validation, Y_validation),
          callbacks=[early_stopping])

'''
出力を用いて予測
'''
truncate = maxlen
Z = X[:1]  # 元データの最初の一部だけ切り出し

original = [f[i] for i in range(maxlen)]
predicted = [None for i in range(maxlen)]

for i in range(length_of_sequences - maxlen + 1):
    z_ = Z[-1:]
    y_ = model.predict(z_)
    sequence_ = np.concatenate(
        (z_.reshape(maxlen, n_in)[1:], y_),
        axis=0).reshape(1, maxlen, n_in)
    Z = np.append(Z, sequence_, axis=0)
    predicted.append(y_.reshape(-1))
# Out:
# Train on 158 samples, validate on 18 samples
# Epoch 1/500
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4942 - val_loss: 0.3467
# Epoch 2/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.3601 - val_loss: 0.1649
# Epoch 3/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.1644 - val_loss: 0.0946
# Epoch 4/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0983 - val_loss: 0.0595
# Epoch 5/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0599 - val_loss: 0.0414
# Epoch 6/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0415 - val_loss: 0.0247
# Epoch 7/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0262 - val_loss: 0.0162
# Epoch 8/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0130
# Epoch 9/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0056
# Epoch 10/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 11/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 12/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 13/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 14/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 15/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 16/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 17/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 18/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 19/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 20/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 21/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 22/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 23/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 24/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 25/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 26/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 27/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 28/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 29/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 30/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 31/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 32/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 33/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 34/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 35/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 36/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 37/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 38/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 39/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 40/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 41/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 42/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 43/500
# 158/158 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 44/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 45/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 46/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 47/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 48/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 49/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 50/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 51/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 52/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 53/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 54/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 55/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 56/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 57/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 58/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 59/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 60/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 61/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 62/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 63/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 64/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 65/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 66/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 67/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 68/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 69/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 70/500
# 158/158 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 71/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 72/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 73/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 74/500
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 00074: early stopping

# %%
# %matplotlib inline

'''
グラフで可視化
'''
plt.rc('font', family='serif')
plt.figure()
plt.plot(toy_problem(T, ampl=0), linestyle='dotted', color='#aaaaaa')
plt.plot(original, linestyle='dashed', color='black')
plt.plot(predicted, color='black')
plt.show()

# %%
# https://github.com/yusugomori/deeplearning-tensorflow-keras/blob/master/5/keras/02_sin_gru_keras.py
